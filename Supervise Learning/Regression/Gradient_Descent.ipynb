# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x = df.iloc[:,-2].values
x
# Out:
# array([92, 56, 88, 70, 80, 49, 65, 35, 66, 67], dtype=int64)

# %%
y = df.iloc[:, -1].values
y
# Out:
# array([98, 68, 81, 80, 83, 52, 66, 30, 68, 73], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y , test_size = 0.2, random_state = 0)

# %%
print("Training data X:", X_train)
print("Testing data X:", X_test)
print("Training labels y:", y_train)
print("Testing labels y:", y_test)
# Out:
# Training data X: [80 67 56 65 35 70 92 49]
# Testing data X: [88 66]
# Training labels y: [83 73 68 66 30 80 98 52]
# Testing labels y: [81 68]

# %%
# each iteration 
def gradient_descent(x, y):
    m_curr = b_curr = 0
    iteration = 10
    learning_rate = 0.001
    n = len(x)
    
#     plt.figure(figsize=(12, 6))
#     plt.scatter(x, y, color='blue', label='Data points')
#     plt.xlabel('X')
#     plt.ylabel('y')
    
    for i in range(iteration):
        y_pred = m_curr * x + b_curr 
        cost = (1/n) * sum([val ** 2 for val in (y - y_pred)])
        md = -(2/n) * sum(x * (y - y_pred))
        bd = -(2/n) * sum(y - y_pred)
        
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        plt.figure(figsize=(12, 6))
        plt.scatter(x, y, color='red', label='Data points')
        plt.xlabel('X')
        plt.ylabel('y')
        plt.plot(x, y_pred, label=f'Iteration {i+1}')
        print(f"Iteration {i+1}: m = {m_curr}, b = {b_curr}, Cost = {cost}")
    
    plt.title('Gradient Descent Regression Line')
    plt.legend()
    plt.show()

# Call gradient_descent function with training data
gradient_descent(X_train, y_train)
# Out:
# Iteration 1: m = 9.46075, b = 0.1375, Cost = 5100.75
# Iteration 2: m = -64.44537625000001, b = -0.9409813750000002, Cost = 310016.2391481251
# Iteration 3: m = 512.9000546191876, b = 7.479631435875, Cost = 18917599.818350267
# Iteration 4: m = -3997.2498092153655, b = -58.30548484556237, Cost = 1154452456.892077
# Iteration 5: m = 31235.47401477466, b = 455.5952266083032, Cost = 70450898506.68114
# Iteration 6: m = -243998.13529200928, b = -3558.936874743457, Cost = 4299292844851.7505
# Iteration 7: m = 1906092.2207689967, b = 27802.07888402922, Cost = 262365979184272.47
# Iteration 8: m = -14890143.350592466, b = -217186.23814255494, Cost = 1.6010983554208332e+16
# Iteration 9: m = 116319937.46047847, b = 1696631.692384862, Cost = 9.770763540691432e+17
# Iteration 10: m = -908676719.2780583, b = -13253873.397171393, Cost = 5.962645570453555e+19

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

def gradient_descent(x, y):
    m_curr = b_curr = 0
    iteration = 10
    learning_rate = 0.01
    n = len(x)
    
    plt.figure(figsize=(12, 6))
    plt.scatter(x, y, color='blue', label='Data points')
    plt.xlabel('X')
    plt.ylabel('y')
    
    for i in range(iteration):
        y_pred = m_curr * x + b_curr 
        cost = (1/n) * sum([val ** 2 for val in (y - y_pred)])
        md = -(2/n) * sum(x * (y - y_pred))
        bd = -(2/n) * sum(y - y_pred)
        
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        
        # Plot the regression line
        if i == 0:
            plt.plot(x, y_pred, color='red', label='Regression Line')
        else:
            plt.plot(x, y_pred, color='red')
        
        print(f"Iteration {i+1}: m = {m_curr}, b = {b_curr}, Cost = {cost}")
    
    plt.title('Gradient Descent Regression Line')
    plt.legend()
    plt.show()

# Call gradient_descent function with training data
gradient_descent(X_train, y_train)
# Out:
# Iteration 1: m = 94.6075, b = 1.375, Cost = 5100.75
# Iteration 2: m = -8147.472625, b = -118.8481375, Cost = 38553872.3779375
# Iteration 3: m = 709892.1929941876, b = 10354.406148375, Cost = 292611216175.4742
# Iteration 4: m = -61844820.8141944, b = -902062.7749721234, Cost = 2220824138080213.5
# Iteration 5: m = 5387843138.1896715, b = 78586574.60176714, Cost = 1.6855334245545101e+19
# Iteration 6: m = -469382120990.0761, b = -6846363588.088994, Cost = 1.2792651505248844e+23
# Iteration 7: m = 40891980315540.93, b = 596446589157.2955, Cost = 9.709207195223613e+26
# Iteration 8: m = -3562457919350588.5, b = -51961677048094.58, Cost = 7.36897306403629e+30
# Iteration 9: m = 3.103568555304432e+17, b = 4526835982858375.0, Cost = 5.592811331207952e+34
# Iteration 10: m = -2.7037899100939575e+19, b = -3.943722600934183e+17, Cost = 4.244762236836699e+38
