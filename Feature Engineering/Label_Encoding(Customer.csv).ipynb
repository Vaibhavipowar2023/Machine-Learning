# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
# Load the dataset
df = pd.read_csv("customer.csv")

# %%
# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
# Select the relevant column for encoding
df1 = df.iloc[:, 2:]  # Adjust this as needed based on your data

# %%
# Display the selected data
print(df1.head())
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
# Initialize LabelEncoder
label = LabelEncoder()

# %%
# Apply label encoding to the 'purchase' column
df1['purchase_encoded'] = label.fit_transform(df1['purchased'])

# %%
df1
# Out:
#      review education purchased  purchase_encoded
# 0   Average    School        No                 0
# 1      Poor        UG        No                 0
# 2      Good        PG        No                 0
# 3      Good        PG        No                 0
# 4   Average        UG        No                 0
# 5   Average    School       Yes                 1
# 6      Good    School        No                 0
# 7      Poor    School       Yes                 1
# 8   Average        UG        No                 0
# 9      Good        UG       Yes                 1
# 10     Good        UG       Yes                 1
# 11     Good        UG       Yes                 1
# 12     Poor    School        No                 0
# 13  Average    School        No                 0
# 14     Poor        PG       Yes                 1
# 15     Poor        UG        No                 0
# 16     Poor        UG       Yes                 1
# 17     Poor        UG       Yes                 1
# ...
